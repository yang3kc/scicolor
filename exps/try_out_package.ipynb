# %%
import scicolor

# %%
scicolor.list_cmaps()
# Out:
#            cm_name          cm_class      cm_type  perceptually_uniform  \
# 0            tab20  multi_sequential  categorical                 False
# 1           tab20b  multi_sequential  categorical                 False
# 2           tab20c  multi_sequential  categorical                 False
# 3           Royal2       categorical  categorical                 False
# 4          Zissou1       categorical  categorical                 False
# 5      Darjeeling1       categorical  categorical                 False
# 6    FantasticFox1       categorical  categorical                 False
# 7        Moonrise3       categorical  categorical                 False
# 8      Cavalcanti1       categorical  categorical                 False
# 9   GrandBudapest2       categorical  categorical                 False
# 10     IsleofDogs2       categorical  categorical                 False
# 11        batlow10        sequential     discrete                  True
# ...

# %%
scicolor.plot_cmaps()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-22bcd1515f23> in <module>
# ----> 1 scicolor.plot_cmaps()
#
# ~/working/scicolor/scicolor/__init__.py in plot_cmaps(cm_name, cm_class, cm_type, perceptually_uniform, color_blind_friendly)
#     234                 "Invalid color map name(s). Please input a string or a list of strings."
#     235             )
# --> 236     cm_list = [[temp_name, get_cmap(temp_name)] for temp_name in cm_name_list]
#     237     _plot_cmaps_gradients(cm_list)
#
# ~/working/scicolor/scicolor/__init__.py in <listcomp>(.0)
#     234                 "Invalid color map name(s). Please input a string or a list of strings."
#     235             )
# --> 236     cm_list = [[temp_name, get_cmap(temp_name)] for temp_name in cm_name_list]
#     237     _plot_cmaps_gradients(cm_list)
#
# ...
