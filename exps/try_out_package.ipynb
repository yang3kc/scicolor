# %%
import scicolor

# %%
color_list = scicolor.list_cmaps()

# %%
color_list
# Out:
#       cm_name          cm_class      cm_type  perceptually_uniform  \
# 0       tab20  multi_sequential  categorical                 False
# 1      tab20b  multi_sequential  categorical                 False
# 2      tab20c  multi_sequential  categorical                 False
# 3      Royal2       categorical  categorical                 False
# 4     Zissou1       categorical  categorical                 False
# ..        ...               ...          ...                   ...
# 60   OKeeffe2       categorical  categorical                 False
# 61  Pillement        sequential     discrete                 False
# 62        Tam        sequential     discrete                 False
# 63       Troy         diverging     discrete                 False
# 64   Veronese  multi_sequential     discrete                 False
#
#     color_blind_friendly
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 60                  True
# 61                  True
# 62                  True
# 63                  True
# 64                  True
#
# [65 rows x 5 columns]

# %%
metbrewer = [
    ["Archambault", "metbrewer", "categorical", "categorical", False, True],
    ["Cassatt1", "metbrewer", "diverging", "discrete", False, True],
    ["Cassatt2", "metbrewer", "multi_sequential", "discrete", False, True],
    ["Demuth", "metbrewer", "diverging", "discrete", False, True],
    ["Derain", "metbrewer", "categorical", "categorical", False, True],
    ["Egypt", "metbrewer", "categorical", "categorical", False, True],
    ["Greek", "metbrewer", "sequential", "discrete", False, True],
    ["Hiroshige", "metbrewer", "diverging", "discrete", False, True],
    ["Hokusai2", "metbrewer", "sequential", "discrete", False, True],
    ["Ingres", "metbrewer", "multi_sequential", "discrete", False, True],
    ["Isfahan1", "metbrewer", "diverging", "discrete", False, True],
    ["Isfahan2", "metbrewer", "categorical", "categorical", False, True],
    ["Java", "metbrewer", "categorical", "categorical", False, True],
    ["Johnson", "metbrewer", "categorical", "categorical", False, True],
    ["Kandinsky", "metbrewer", "categorical", "categorical", False, True],
    ["Morgenstern", "metbrewer", "diverging", "discrete", False, True],
    ["OKeeffe1", "metbrewer", "diverging", "discrete", False, True],
    ["OKeeffe2", "metbrewer", "categorical", "categorical", False, True],
    ["Pillement", "metbrewer", "sequential", "discrete", False, True],
    ["Tam", "metbrewer", "sequential", "discrete", False, True],
    ["Troy", "metbrewer", "diverging", "discrete", False, True],
    ["Veronese", "metbrewer", "multi_sequential", "discrete", False, True]
]

# %%
for x in metbrewer])
# Out:
#   File "<ipython-input-6-ba46164066cb>", line 1
#     for x in metbrewer])
#                       ^
# SyntaxError: unmatched ']'

# %%
color_list.query("cm_name == ")
# Out:
# Traceback (most recent call last):
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-7-5c8c260c688b>", line 1, in <module>
#     color_list.query("cm_name == ")
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3341, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3471, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/computation/eval.py", line 341, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 787, in __init__
#     self.terms = self.parse()
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 806, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 394, in visit
#     raise e
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 390, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/Users/yangkc/anaconda3/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     cm_name ==
#               ^
# SyntaxError: invalid syntax

# %%
set(color_list.cm_class)
# Out:
# {'categorical', 'diverging', 'misc', 'multi_sequential', 'sequential'}

# %%
set(color_list.cm_type)
# Out:
# {'categorical', 'continuous', 'discrete'}

# %%
color_list_full = scicolor.color_info_df

# %%
', '.join(list(color_list_full.query("source == 'ocean'").cm_name))
# Out:
# 'topo'

# %%
scicolor.plot_cmaps(cm_type="discrete", color_blind_friendly=True)

# %%
scicolor.get_cmap("oleron10").colors
# Out:
# ['#1A2659',
#  '#455285',
#  '#7784B7',
#  '#AAB7E8',
#  '#D3E0FA',
#  '#3C5600',
#  '#7A711F',
#  '#B79A5E',
#  '#F1CEA4',
#  '#FDFDE6']

# %%
scicolor.plot_cmaps()

# %%
scicolor.plot_cmaps(cm_class='sequential')

# %%
scicolor.plot_cmaps(cm_class='diverging')

# %%
scicolor.plot_cmaps(cm_class='categorical')

# %%
scicolor.plot_cmaps(cm_class='multi_sequential')

# %%
scicolor.plot_cmaps(cm_type='continuous')

# %%
scicolor.plot_cmaps(perceptually_uniform=False)

# %%
scicolor.plot_cmaps(color_blind_friendly=True)

# %%
scicolor.plot_cmaps(color_blind_friendly=False)

# %%
scicolor.get_cmap("Veronese").colors
# Out:
# ['#67322e', '#99610a', '#c38f16', '#6e948c', '#2c6b67', '#175449', '#122c43']
